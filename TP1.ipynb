# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
chemin="C:\\Users\\Maouloud\\Downloads\\auto-mpg.csv"

# Charger le dataset
mpg_data = pd.read_csv(chemin)  # Assurez-vous de mettre le bon nom de fichier

# Définir les variables indépendante et dépendante
X = mpg_data['displacement']  # Remplacez 'variable_indépendante' par le nom de votre colonne
y = mpg_data['mpg']  # Remplacez 'variable_dépendante' par le nom de votre colonne

# Calculer les coefficients de la régression linéaire
coefficients = np.polyfit(X, y, 1)
polynomial = np.poly1d(coefficients)

# Tracer les points de données
plt.scatter(X, y, color='blue', label='Data Points')

# Tracer la régression linéaire
plt.plot(X, polynomial(X), color='red', label='Linear Regression')

# Ajouter des labels et un titre
plt.xlabel('Variable Indépendante')
plt.ylabel('Variable Dépendante')
plt.title('Régression Linéaire avec Matplotlib')
plt.legend()

# Afficher le graphique
plt.show()
